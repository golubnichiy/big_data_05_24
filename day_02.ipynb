# %% [markdown]
# ### Изображения

# %% [markdown]
# ### Подключаем библиотеки

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv('HWS.csv')

# %%
data.head()
# Out:
#    Gender  Height  Weight  Index
# 0    Male     174      96      4
# 1    Male     189      87      2
# 2  Female     185     110      4
# 3  Female     195     104      3
# 4    Male     149      61      3

# %%
data.shape
# Out:
# (500, 4)

# %% [markdown]
# ### Гистограмма

# %%
data['Height'].hist()
plt.show()

# %%
data['Height'].hist(bins=8)
plt.show()

# %% [markdown]
# ### Столбчатая диаграмма

# %%
data_gr_height = data.groupby('Index')['Height'].mean()
print(data_gr_height)
# Out:
# Index
# 0    187.538462
# 1    184.772727
# 2    174.260870
# 3    175.985294
# 4    173.876923
# 5    160.979798
# Name: Height, dtype: float64

# %%
data_gr_height.plot(kind='bar', title='Средний рост по индексу массы тела')
plt.show()

# %% [markdown]
# ### Загрузка датасета качество атмосферного воздуха

# %%
aq = pd.read_csv('aq.csv')
print(aq)
# Out:
#                 City        Date  PM2.5   PM10     NO    NO2    NOx    NH3  \
# 0          Ahmedabad  2015-01-01    NaN    NaN   0.92  18.22  17.15    NaN
# 1          Ahmedabad  2015-01-02    NaN    NaN   0.97  15.69  16.46    NaN
# 2          Ahmedabad  2015-01-03    NaN    NaN  17.40  19.30  29.70    NaN
# 3          Ahmedabad  2015-01-04    NaN    NaN   1.70  18.48  17.97    NaN
# 4          Ahmedabad  2015-01-05    NaN    NaN  22.10  21.42  37.76    NaN
# ...              ...         ...    ...    ...    ...    ...    ...    ...
# 29526  Visakhapatnam  2020-06-27  15.02  50.94   7.68  25.06  19.54  12.47
# 29527  Visakhapatnam  2020-06-28  24.38  74.09   3.42  26.06  16.53  11.99
# 29528  Visakhapatnam  2020-06-29  22.91  65.73   3.45  29.53  18.33  10.71
# 29529  Visakhapatnam  2020-06-30  16.64  49.97   4.05  29.26  18.80  10.03
# 29530  Visakhapatnam  2020-07-01  15.00  66.00   0.40  26.85  14.05   5.20
#
# ...

# %%
aq.plot(x='Date', y='NO2', rot=45)
plt.grid(True)
plt.show()

# %% [markdown]
# ### Диаграмма рассеяния

# %%
data.plot(x='Height', y='Weight', kind='scatter')
plt.show()

# %% [markdown]
# ### Добавление уровней

# %%
data[data['Gender']=='Male']['Height'].hist(bins=25, alpha=0.7)
data[data['Gender']=='Female']['Height'].hist(bins=25, alpha=0.7)
plt.legend(['Male', 'Female'])
plt.show()

# %% [markdown]
# ### Пропущенные значения

# %%
print(aq)
# Out:
#                 City        Date  PM2.5   PM10     NO    NO2    NOx    NH3  \
# 0          Ahmedabad  2015-01-01    NaN    NaN   0.92  18.22  17.15    NaN
# 1          Ahmedabad  2015-01-02    NaN    NaN   0.97  15.69  16.46    NaN
# 2          Ahmedabad  2015-01-03    NaN    NaN  17.40  19.30  29.70    NaN
# 3          Ahmedabad  2015-01-04    NaN    NaN   1.70  18.48  17.97    NaN
# 4          Ahmedabad  2015-01-05    NaN    NaN  22.10  21.42  37.76    NaN
# ...              ...         ...    ...    ...    ...    ...    ...    ...
# 29526  Visakhapatnam  2020-06-27  15.02  50.94   7.68  25.06  19.54  12.47
# 29527  Visakhapatnam  2020-06-28  24.38  74.09   3.42  26.06  16.53  11.99
# 29528  Visakhapatnam  2020-06-29  22.91  65.73   3.45  29.53  18.33  10.71
# 29529  Visakhapatnam  2020-06-30  16.64  49.97   4.05  29.26  18.80  10.03
# 29530  Visakhapatnam  2020-07-01  15.00  66.00   0.40  26.85  14.05   5.20
#
# ...

# %%
print(aq.isna())
# Out:
#         City   Date  PM2.5   PM10     NO    NO2    NOx    NH3     CO    SO2  \
# 0      False  False   True   True  False  False  False   True  False  False
# 1      False  False   True   True  False  False  False   True  False  False
# 2      False  False   True   True  False  False  False   True  False  False
# 3      False  False   True   True  False  False  False   True  False  False
# 4      False  False   True   True  False  False  False   True  False  False
# ...      ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 29526  False  False  False  False  False  False  False  False  False  False
# 29527  False  False  False  False  False  False  False  False  False  False
# 29528  False  False  False  False  False  False  False  False  False  False
# 29529  False  False  False  False  False  False  False  False  False  False
# 29530  False  False  False  False  False  False  False  False  False  False
#
# ...

# %%
print(aq.isna().any())
# Out:
# City          False
# Date          False
# PM2.5          True
# PM10           True
# NO             True
# NO2            True
# NOx            True
# NH3            True
# CO             True
# SO2            True
# O3             True
# Benzene        True
# Toluene        True
# Xylene         True
# AQI            True
# AQI_Bucket     True
# dtype: bool

# %%
print(aq.isna().sum())
# Out:
# City              0
# Date              0
# PM2.5          4598
# PM10          11140
# NO             3582
# NO2            3585
# NOx            4185
# NH3           10328
# CO             2059
# SO2            3854
# O3             4022
# Benzene        5623
# Toluene        8041
# Xylene        18109
# AQI            4681
# AQI_Bucket     4681
# dtype: int64

# %%
aq.isna().sum().plot(kind='bar')
plt.show()

# %% [markdown]
# ### Решение задачи удаления пробельных значений

# %%
aq.dropna()
# Out:
#                 City        Date  PM2.5    PM10    NO    NO2    NOx    NH3  \
# 2123       Amaravati  2017-11-25  81.40  124.50  1.44  20.50  12.08  10.72
# 2124       Amaravati  2017-11-26  78.32  129.06  1.26  26.00  14.85  10.28
# 2125       Amaravati  2017-11-27  88.76  135.32  6.60  30.85  21.77  12.91
# 2126       Amaravati  2017-11-28  64.18  104.09  2.56  28.07  17.01  11.42
# 2127       Amaravati  2017-11-29  72.47  114.84  5.23  23.20  16.59  12.25
# ...              ...         ...    ...     ...   ...    ...    ...    ...
# 29525  Visakhapatnam  2020-06-26   7.63   32.27  5.91  23.27  17.19  11.15
# 29526  Visakhapatnam  2020-06-27  15.02   50.94  7.68  25.06  19.54  12.47
# 29527  Visakhapatnam  2020-06-28  24.38   74.09  3.42  26.06  16.53  11.99
# 29528  Visakhapatnam  2020-06-29  22.91   65.73  3.45  29.53  18.33  10.71
# 29529  Visakhapatnam  2020-06-30  16.64   49.97  4.05  29.26  18.80  10.03
#
# ...

# %%
aq.fillna(0)
# Out:
#                 City        Date  PM2.5   PM10     NO    NO2    NOx    NH3  \
# 0          Ahmedabad  2015-01-01   0.00   0.00   0.92  18.22  17.15   0.00
# 1          Ahmedabad  2015-01-02   0.00   0.00   0.97  15.69  16.46   0.00
# 2          Ahmedabad  2015-01-03   0.00   0.00  17.40  19.30  29.70   0.00
# 3          Ahmedabad  2015-01-04   0.00   0.00   1.70  18.48  17.97   0.00
# 4          Ahmedabad  2015-01-05   0.00   0.00  22.10  21.42  37.76   0.00
# ...              ...         ...    ...    ...    ...    ...    ...    ...
# 29526  Visakhapatnam  2020-06-27  15.02  50.94   7.68  25.06  19.54  12.47
# 29527  Visakhapatnam  2020-06-28  24.38  74.09   3.42  26.06  16.53  11.99
# 29528  Visakhapatnam  2020-06-29  22.91  65.73   3.45  29.53  18.33  10.71
# 29529  Visakhapatnam  2020-06-30  16.64  49.97   4.05  29.26  18.80  10.03
# 29530  Visakhapatnam  2020-07-01  15.00  66.00   0.40  26.85  14.05   5.20
#
# ...
